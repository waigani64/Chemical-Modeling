# %% [markdown]
# <a href="https://colab.research.google.com/github/waigani64/Chemical-Modeling/blob/main/Simple_Hisotgram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


# Particle size data
particle_sizes = [237.5, 307.6, 275.4, 291.4, 302.4, 264.6, 291.4, 313.0, 313.0, 313.0, 318.4, 318.4, 318.4]

# Plot the histogram
plt.hist(particle_sizes, bins=5, edgecolor='black')
plt.xlabel('Particle Size')
plt.ylabel('Frequency')
plt.title('Particle Size Distribution')
plt.show()
